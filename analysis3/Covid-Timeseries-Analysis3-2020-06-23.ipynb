# %% [markdown]
# # Get datasets

# %%
# import main libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
# %matplotlib inline

# %%
# Find correct folder to use - /Users/shim/Desktop/AI/CovidbyGovt
# %pwd
# Out:
# '/Users/shim2020/Desktop/current/Classes/00_AI/githubs/CovidbyGovt/analysis3'

# %% [markdown]
# ## Import Covid-19 global data

# %%
# direct link to John Hopkins global timeset data 
data = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"

covid = pd.read_csv(data, sep=",")

# preview our data
covid.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/24/20  6/25/20  6/26/20  6/27/20  \
# 0        0        0        0  ...      639      675      683      703
# 1        0        0        0  ...       47       49       51       53
# 2        0        0        0  ...      869      878      885      892
# 3        0        0        0  ...       52       52       52       52
# 4        0        0        0  ...       10       10       10       10
#
#    6/28/20  6/29/20  6/30/20  7/1/20  7/2/20  7/3/20
# 0      721      733      746     774     807     819
# 1       55       58       62      65      69      72
# 2      897      905      912     920     928     937
# 3       52       52       52      52      52      52
# 4       11       11       13      15      17      18
#
# [5 rows x 168 columns]

# %% [markdown]
# ## Quick analysis of data

# %%
today = datetime.now()

# if time is after 5pm (Tucson time), then use today's date 
today5pm = today.replace(hour=17, minute=1, second=0, microsecond=0)
if today > today5pm:
    date = today  

# otherwise use yesterday's date
else:
    date = today - timedelta(1)

# date in string format
date = date.strftime('%D').lstrip("0").replace(" 0", " ")
date = date.replace("/0", "/")
date
# Out:
# '7/3/20'

# %%
# get WW death total
covid[[date]].sum()
# Out:
# 7/3/20    525121
# dtype: int64

# %%
# get US death counts
covid[date][covid["Country/Region"]=='US'].sum()
# Out:
# 129434

# %% [markdown]
# ## Visualize data

# %%
# get country totals 
country_totals = covid.groupby(['Country/Region']).sum().reset_index()
country_totals.rename(columns = {date:"deaths", "Country/Region": "country"}, inplace = True)
country_totals[['country', 'deaths']].sort_values(by="deaths", ascending=False).head(20)
# Out:
#             country  deaths
# 174              US  129434
# 23           Brazil   61884
# 178  United Kingdom   44216
# 85            Italy   34833
# 62           France   29896
# 113          Mexico   29843
# 158           Spain   28385
# 79            India   18655
# 81             Iran   11260
# 134            Peru   10226
# 140          Russia    9844
# 16          Belgium    9765
# 66          Germany    9010
# 32           Canada    8722
# 122     Netherlands    6132
# 35            Chile    6051
# 162          Sweden    5420
# 173          Turkey    5186
# 52          Ecuador    4700
# 36            China    4641

# %%
# add value labels on chart
def show_values_on_bars(axs, h_v="v", space=0.4):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                # format values on chart
                ax.text(_x, _y, f"{value:,.0f}", ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - float(space/2)
                value = int(p.get_width())
                # format values on chart
                ax.text(_x, _y, f" {value:,.0f}", ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# select subplot SIZE
fig, ax = plt.subplots(figsize=(10, 6))  

# REPLACE data
data = country_totals.sort_values(by='deaths', ascending=False).head(20)
g = sns.barplot(ax=ax, x='deaths', y='country', data=data)

# set DATE
current_date = str(date)

# put VALUES on selected data
show_values_on_bars(g, "h")  

# remove SPINES
sns.despine(left=True, bottom=True)
sns.set_style('white')

# remove LABELS.
g.set_ylabel('')    
g.set_xlabel('')

# remove bottom TICKS
g.set(xticks=[])

# set TITLE
g.set_title("Covid-19 - Current WW Deaths - Top 20 Countries - {}".format(current_date))

# SAVE graph to a file
g.figure.savefig("top20_countries.png")

# %% [markdown]
# ## Investigate ICU Dataset

# %%
icu = pd.read_excel('../data/Other/ICU/KHN_ICU_bed_county_analysis_2.xlsx')
icu.head()
# Out:
#    cnty_fips cnty_name  st    state  hospitals_in_cost_reports  \
# 0       1001   Autauga  AL  Alabama                          1
# 1       1003   Baldwin  AL  Alabama                          3
# 2       1005   Barbour  AL  Alabama                          1
# 3       1007      Bibb  AL  Alabama                          1
# 4       1009    Blount  AL  Alabama                          1
#
#    Hospitals_in_HC  all_icu  Total_pop  60plus  60plus_pct  \
# 0                1        6      55036   10523       0.191
# 1                3       51     203360   53519       0.263
# 2                1        5      26201    6150       0.235
# 3                1        0      22580    4773       0.211
# 4                1        6      57667   13600       0.236
#
#    60plus_per_each_icu_bed
# 0                   1754.0
# 1                   1049.0
# 2                   1230.0
# 3                      NaN
# 4                   2267.0

# %%
# check data
icu.isna().sum()
# Out:
# cnty_fips                       0
# cnty_name                       0
# st                              0
# state                           0
# hospitals_in_cost_reports       0
# Hospitals_in_HC                 0
# all_icu                         0
# Total_pop                       0
# 60plus                          0
# 60plus_pct                      0
# 60plus_per_each_icu_bed      1665
# dtype: int64

# %%
# remove column
icu.drop(['60plus_per_each_icu_bed'], axis=1, inplace=True)

# %%
# AZ ICU beds by Population
AZ_icu = icu[icu['st'] == 'AZ'].sort_values(by="Total_pop", ascending=False).head(15)
AZ_icu
# Out:
#      cnty_fips   cnty_name  st    state  hospitals_in_cost_reports  \
# 103       4013    Maricopa  AZ  Arizona                         31
# 106       4019        Pima  AZ  Arizona                          9
# 107       4021       Pinal  AZ  Arizona                          4
# 109       4025     Yavapai  AZ  Arizona                          2
# 104       4015      Mohave  AZ  Arizona                          4
# 110       4027        Yuma  AZ  Arizona                          1
# 98        4005    Coconino  AZ  Arizona                          3
# 97        4003     Cochise  AZ  Arizona                          4
# 105       4017      Navajo  AZ  Arizona                          4
# 96        4001      Apache  AZ  Arizona                          4
# 99        4007        Gila  AZ  Arizona                          3
# 108       4023  Santa Cruz  AZ  Arizona                          1
# 100       4009      Graham  AZ  Arizona                          1
# 102       4012      La Paz  AZ  Arizona                          2
# 101       4011    Greenlee  AZ  Arizona                          0
#
#      Hospitals_in_HC  all_icu  Total_pop  60plus  60plus_pct
# 103               34     1004    4155501  808534       0.195
# 106                9      296    1007257  245814       0.244
# 107                4       22     405537  100086       0.247
# 109                2       39     220972   85127       0.385
# 104                4       80     204691   73559       0.359
# 110                1       42     204281   45739       0.224
# 98                 3       41     138639   23195       0.167
# 97                 4       12     126516   35231       0.278
# 105                4       12     107902   24267       0.225
# 96                 4        0      71602   14107       0.197
# 99                 3        8      53145   18752       0.353
# 108                1        0      46358   10530       0.227
# 100                1        0      37700    6933       0.184
# 102                2        3      20477    9183       0.448
# 101                0        0       9368    1631       0.174

# %% [markdown]
# # US by State covid data - merged with ICU data

# %%
# direct link to John Hopkins US timeset data 
data2 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv"

covid_US = pd.read_csv(data2, sep=",")

# preview our data
covid_US.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 6/24/20  6/25/20  6/26/20  6/27/20  6/28/20  \
# 0 -14.2710 -170.1320  ...       0        0        0        0        0
# 1  13.4443  144.7937  ...       5        5        5        5        5
# 2  15.0979  145.6739  ...       2        2        2        2        2
# 3  18.2208  -66.5901  ...     149      151      151      152      153
# 4  18.3358  -64.8963  ...       6        6        6        6        6
#
#    6/29/20  6/30/20  7/1/20  7/2/20  7/3/20
# 0        0        0       0       0       0
# 1        5        5       5       5       5
# 2        2        2       2       2       2
# 3      153      153     153     153     154
# 4        6        6       6       6       6
#
# [5 rows x 176 columns]

# %%
covid_US.shape
# Out:
# (3261, 176)

# %%
# check US death counts
covid_US[date].sum()
# Out:
# 129434

# %% [markdown]
# Missing a data point with the global data - because of changing data, I'm not going to worry about this now.

# %%
# merge icu with Covid_US deaths - outer join to collect all deaths (some deaths may not be isolated to county level)
left = covid_US
right = icu
county_deaths = pd.merge(left, right, 
              how='outer', on=None, 
              left_on="FIPS", right_on="cnty_fips")
county_deaths
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2  \
# 0           16   AS  ASM     16     60.0         NaN
# 1          316   GU  GUM    316     66.0         NaN
# 2          580   MP  MNP    580     69.0         NaN
# 3          630   PR  PRI    630     72.0         NaN
# 4          850   VI  VIR    850     78.0         NaN
# ...        ...  ...  ...    ...      ...         ...
# 3256  84090053   US  USA    840  90053.0  Unassigned
# 3257  84090054   US  USA    840  90054.0  Unassigned
# 3258  84090055   US  USA    840  90055.0  Unassigned
# 3259  84090056   US  USA    840  90056.0  Unassigned
# 3260  84099999   US  USA    840  99999.0         NaN
#
#                 Province_State Country_Region      Lat     Long_  ...  \
# 0               American Samoa             US -14.2710 -170.1320  ...
# 1                         Guam             US  13.4443  144.7937  ...
# 2     Northern Mariana Islands             US  15.0979  145.6739  ...
# 3                  Puerto Rico             US  18.2208  -66.5901  ...
# 4               Virgin Islands             US  18.3358  -64.8963  ...
# ...                        ...            ...      ...       ...  ...
# 3256                Washington             US   0.0000    0.0000  ...
# 3257             West Virginia             US   0.0000    0.0000  ...
# 3258                 Wisconsin             US   0.0000    0.0000  ...
# 3259                   Wyoming             US   0.0000    0.0000  ...
# 3260            Grand Princess             US   0.0000    0.0000  ...
#
#      cnty_fips  cnty_name   st  state  hospitals_in_cost_reports  \
# 0          NaN        NaN  NaN    NaN                        NaN
# 1          NaN        NaN  NaN    NaN                        NaN
# 2          NaN        NaN  NaN    NaN                        NaN
# 3          NaN        NaN  NaN    NaN                        NaN
# 4          NaN        NaN  NaN    NaN                        NaN
# ...        ...        ...  ...    ...                        ...
# 3256       NaN        NaN  NaN    NaN                        NaN
# 3257       NaN        NaN  NaN    NaN                        NaN
# 3258       NaN        NaN  NaN    NaN                        NaN
# 3259       NaN        NaN  NaN    NaN                        NaN
# 3260       NaN        NaN  NaN    NaN                        NaN
#
#       Hospitals_in_HC  all_icu  Total_pop  60plus  60plus_pct
# 0                 NaN      NaN        NaN     NaN         NaN
# 1                 NaN      NaN        NaN     NaN         NaN
# 2                 NaN      NaN        NaN     NaN         NaN
# 3                 NaN      NaN        NaN     NaN         NaN
# 4                 NaN      NaN        NaN     NaN         NaN
# ...               ...      ...        ...     ...         ...
# 3256              NaN      NaN        NaN     NaN         NaN
# 3257              NaN      NaN        NaN     NaN         NaN
# 3258              NaN      NaN        NaN     NaN         NaN
# 3259              NaN      NaN        NaN     NaN         NaN
# 3260              NaN      NaN        NaN     NaN         NaN
#
# [3261 rows x 186 columns]

# %%
# remove columns that are doubled by merge
county_deaths.drop(columns=['cnty_fips','cnty_name','state'])
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2  \
# 0           16   AS  ASM     16     60.0         NaN
# 1          316   GU  GUM    316     66.0         NaN
# 2          580   MP  MNP    580     69.0         NaN
# 3          630   PR  PRI    630     72.0         NaN
# 4          850   VI  VIR    850     78.0         NaN
# ...        ...  ...  ...    ...      ...         ...
# 3256  84090053   US  USA    840  90053.0  Unassigned
# 3257  84090054   US  USA    840  90054.0  Unassigned
# 3258  84090055   US  USA    840  90055.0  Unassigned
# 3259  84090056   US  USA    840  90056.0  Unassigned
# 3260  84099999   US  USA    840  99999.0         NaN
#
#                 Province_State Country_Region      Lat     Long_  ... 7/1/20  \
# 0               American Samoa             US -14.2710 -170.1320  ...      0
# 1                         Guam             US  13.4443  144.7937  ...      5
# 2     Northern Mariana Islands             US  15.0979  145.6739  ...      2
# 3                  Puerto Rico             US  18.2208  -66.5901  ...    153
# 4               Virgin Islands             US  18.3358  -64.8963  ...      6
# ...                        ...            ...      ...       ...  ...    ...
# 3256                Washington             US   0.0000    0.0000  ...      0
# 3257             West Virginia             US   0.0000    0.0000  ...      0
# 3258                 Wisconsin             US   0.0000    0.0000  ...      0
# 3259                   Wyoming             US   0.0000    0.0000  ...     19
# 3260            Grand Princess             US   0.0000    0.0000  ...      3
#
#       7/2/20  7/3/20   st  hospitals_in_cost_reports  Hospitals_in_HC  \
# 0          0       0  NaN                        NaN              NaN
# 1          5       5  NaN                        NaN              NaN
# 2          2       2  NaN                        NaN              NaN
# 3        153     154  NaN                        NaN              NaN
# 4          6       6  NaN                        NaN              NaN
# ...      ...     ...  ...                        ...              ...
# 3256       0       0  NaN                        NaN              NaN
# 3257       0       0  NaN                        NaN              NaN
# 3258       0       0  NaN                        NaN              NaN
# 3259      19      19  NaN                        NaN              NaN
# 3260       3       3  NaN                        NaN              NaN
#
#       all_icu  Total_pop  60plus  60plus_pct
# 0         NaN        NaN     NaN         NaN
# 1         NaN        NaN     NaN         NaN
# 2         NaN        NaN     NaN         NaN
# 3         NaN        NaN     NaN         NaN
# 4         NaN        NaN     NaN         NaN
# ...       ...        ...     ...         ...
# 3256      NaN        NaN     NaN         NaN
# 3257      NaN        NaN     NaN         NaN
# 3258      NaN        NaN     NaN         NaN
# 3259      NaN        NaN     NaN         NaN
# 3260      NaN        NaN     NaN         NaN
#
# [3261 rows x 183 columns]

# %% [markdown]
# # Visualize - US State Data

# %%
# group the state deaths
states = county_deaths[['Province_State', date]].copy()
states = states.groupby(['Province_State'], sort=False).sum().reset_index()

# show descending
states = states.sort_values(by=date, ascending=False)
states.head(10)
# Out:
#    Province_State  7/3/20
# 37       New York   32137
# 35     New Jersey   15164
# 26  Massachusetts    8149
# 18       Illinois    7005
# 43   Pennsylvania    6746
# 9      California    6315
# 27       Michigan    6215
# 11    Connecticut    4335
# 14        Florida    3684
# 23      Louisiana    3278

# %%
# check total deaths
states[date].sum()
# Out:
# 129434

# %%
# function for setting horizontal labels
def show_values_on_bars(axs, h_v="v", space=0.4):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                # format values on chart
                ax.text(_x, _y, f"{value:,.0f}", ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                # format values on chart
                ax.text(_x, _y, f" {value:,.0f}", ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# SET subplot size
fig, ax = plt.subplots(figsize=(10, 6))  

# REPLACE dataset
data = states.head(30)
current_date = str(date)

# plot VALUES on selected data
g = sns.barplot(ax=ax, x=date, y='Province_State', data=data)
show_values_on_bars(g, "h")  

# remove spines
sns.despine(left=True, bottom=True)
sns.set_style('white')

# remove labels.
g.set_ylabel('')    
g.set_xlabel('')

# remove bottom values
g.set(xticks=[])

# set TITLE
g.set_title("Covid-19 Current 30 Most Deaths - US States - {}".format(current_date))

# save graph to a FILENAME
g.figure.savefig("US_states30.png")

# %% [markdown]
# ## Visualize - AZ County Deaths

# %%
# tally of county deaths
co = county_deaths[['Admin2', 'Province_State', date]].copy()
co.rename(columns = {'Admin2':'county','Province_State':'state',date:'total_deaths'}, inplace = True)
co = co.sort_values(by='total_deaths', ascending=False)
co.head(10)
# Out:
#             county          state  total_deaths
# 1863      New York       New York         23140
# 615           Cook       Illinois          4618
# 209    Los Angeles     California          3457
# 1317         Wayne       Michigan          2728
# 1862        Nassau       New York          2185
# 1785         Essex     New Jersey          2034
# 1780        Bergen     New Jersey          2000
# 1884       Suffolk       New York          1983
# 1230     Middlesex  Massachusetts          1870
# 2299  Philadelphia   Pennsylvania          1619

# %%
# check total deaths
co["total_deaths"].sum()
# Out:
# 129434

# %%
# check AZ totals by county
AZ_county = co[co['state']=='Arizona']
AZ_county
# Out:
#           county    state  total_deaths
# 108     Maricopa  Arizona           865
# 111         Pima  Arizona           282
# 110       Navajo  Arizona           132
# 115         Yuma  Arizona           107
# 103     Coconino  Arizona            96
# 101       Apache  Arizona            91
# 109       Mohave  Arizona            88
# 112        Pinal  Arizona            75
# 113   Santa Cruz  Arizona            24
# 102      Cochise  Arizona            14
# 114      Yavapai  Arizona            10
# 107       La Paz  Arizona             6
# 104         Gila  Arizona             6
# 106     Greenlee  Arizona             1
# 105       Graham  Arizona             1
# 3211  Unassigned  Arizona             0
# 3159   Out of AZ  Arizona             0

# %% [markdown]
# Hmmm...Unassigned and Out of AZ need to reassigned ... eventually...for now I'll keep them in the totals

# %%
# deaths in AZ - check with chart of states
AZ_county['total_deaths'].sum()
# Out:
# 1798

# %%
# add values on chart
def show_values_on_bars(axs, h_v="v", space=0.4):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                # format values on chart
                ax.text(_x, _y, f"{value:,.0f}", ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()+ float(space/2)
                value = int(p.get_width())
                # format values on chart
                ax.text(_x, _y, f" {value:,.0f}", ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# select subplot size
fig, ax = plt.subplots(figsize=(8, 4))  

# put values on selected data
data = AZ_county[AZ_county['total_deaths'] >= 1]
g = sns.barplot(ax=ax, x='total_deaths', y='county', data=data)
show_values_on_bars(g, "h")  

# remove spines
sns.despine(left=True, bottom=True)
sns.set_style('white')

# remove labels.
g.set_ylabel('')    
g.set_xlabel('')

# remove bottom values
g.set(xticks=[])

# set title
g.set_title("Covid-19 Current Deaths - By AZ counties - {}".format(str(date)))

# save graph to a file
g.figure.savefig("AZ_counties_list.png")

# %% [markdown]
# # Timeseries - Worldwide

# %%
# look at past month worldwide
covid_ww = covid.iloc[:, 4:].sum(axis=0)
df = covid_ww.tail(30)
df.tail()
# Out:
# 6/29/20    506076
# 6/30/20    511268
# 7/1/20     516253
# 7/2/20     521361
# 7/3/20     525121
# dtype: int64

# %%
# simple graph
fig, ax = plt.subplots(figsize=(16, 6))
sns.lineplot(x=df.index, y=df, sort=False, linewidth=2)
sns.despine(right=True, top=True)
ax.lines[0].set_linestyle("--")
plt.xticks(rotation=45)
ax.legend(['WW Deaths - {}'.format(str(date))]) 
plt.title("Worldwide Covid-19 Deaths - {}".format(str(date)))
plt.show()
# save graph to a file
fig.savefig("WW_deaths.png")

# %%
# look at logarithmic growth
import matplotlib.ticker as ticker

fig, ax = plt.subplots(figsize=(16, 6))
ax.set(yscale="log")
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)) )
sns.lineplot(x=df.index, y=df, sort=False, linewidth=2, color='red')
sns.despine(right=True, top=True)
ax.lines[0].set_linestyle("-")
plt.xticks(rotation=45)
ax.legend(['Logarithmic - WW Deaths']) 
plt.title("Worldwide Covid-19 Deaths (logarithmic scale) - {}".format(str(date)))
plt.show()
# save graph to a file
fig.savefig("WW_deaths_log.png")

# %% [markdown]
# ## WW - > Multiple Country Timeseries

# %%
# melt dataset - Keep certain columns and change others to vertical axis(?)
covid_ww_long = pd.melt(covid, id_vars=covid.iloc[:, :4],
var_name='Date', value_name='Deaths')
covid_ww_long
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 0                NaN            Afghanistan  33.000000  65.000000  1/22/20
# 1                NaN                Albania  41.153300  20.168300  1/22/20
# 2                NaN                Algeria  28.033900   1.659600  1/22/20
# 3                NaN                Andorra  42.506300   1.521800  1/22/20
# 4                NaN                 Angola -11.202700  17.873900  1/22/20
# ...              ...                    ...        ...        ...      ...
# 43619            NaN  Sao Tome and Principe   0.186360   6.613081   7/3/20
# 43620            NaN                  Yemen  15.552727  48.516388   7/3/20
# 43621            NaN                Comoros -11.645500  43.333300   7/3/20
# 43622            NaN             Tajikistan  38.861034  71.276093   7/3/20
# 43623            NaN                Lesotho -29.609988  28.233608   7/3/20
#
#        Deaths
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 43619      13
# 43620     335
# 43621       7
# 43622      52
# 43623       0
#
# [43624 rows x 6 columns]

# %%
# group countries by date - sort is False here because the date is not the sort
countries = covid_ww_long.groupby(['Date', 'Country/Region'], sort=False).sum().reset_index()

# drop columns that don't make sense
countries.drop(['Lat','Long'], axis=1, inplace=True)

# look at timeseries 
countries
# Out:
#           Date         Country/Region  Deaths
# 0      1/22/20            Afghanistan       0
# 1      1/22/20                Albania       0
# 2      1/22/20                Algeria       0
# 3      1/22/20                Andorra       0
# 4      1/22/20                 Angola       0
# ...        ...                    ...     ...
# 30827   7/3/20  Sao Tome and Principe      13
# 30828   7/3/20                  Yemen     335
# 30829   7/3/20                Comoros       7
# 30830   7/3/20             Tajikistan      52
# 30831   7/3/20                Lesotho       0
#
# [30832 rows x 3 columns]

# %%
# check that it matches above summary
top = countries[countries['Date']==date].sort_values(by='Deaths', ascending = False).head(10)
top
# Out:
#          Date  Country/Region  Deaths
# 30800  7/3/20              US  129434
# 30665  7/3/20          Brazil   61884
# 30798  7/3/20  United Kingdom   44216
# 30721  7/3/20           Italy   34833
# 30700  7/3/20          France   29896
# 30742  7/3/20          Mexico   29843
# 30782  7/3/20           Spain   28385
# 30715  7/3/20           India   18655
# 30717  7/3/20            Iran   11260
# 30762  7/3/20            Peru   10226

# %%
# total deaths in top
top['Deaths'].sum()
# Out:
# 398632

# %% [markdown]
# ### Worldwide Timeseries - Graphs

# %%
# add a column for LEGEND to top
top['legend']= top['Country/Region'] + ' - ' + top['Deaths'].astype(str)

# %%
# SET subplot size
fig, ax = plt.subplots(figsize=(10, 6))  

# set ATTRIBUTEs for each dataset
for i in top['Country/Region']:
    # set data to last 30 days
    df = countries[countries['Country/Region' ] == i].tail(30)
    # set graph
    g = sns.lineplot(ax=ax, x='Date', y='Deaths', data=df, sort=False, linewidth=2)  

# set date 
current_date = str(date) 

# remove spines
sns.despine(right=True, top=True)
sns.set_style('white')

# set TITLE
g.set_title("Countries with the most Covid-19 deaths over the last 30 days - {}".format(current_date))

# set extras
g.set_xlabel("")
plt.legend(top['legend'])
plt.xticks(rotation=45)
plt.show()

# save graph to a FILENAME
fig.savefig("Top10_countries.png")

# %%
# SET subplot size
fig, ax = plt.subplots(figsize=(10, 6))  

# set log scale
ax.set(yscale="log")
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)) )

# set ATTRIBUTEs for each dataset
for i in top['Country/Region']:
    # set data to last 30 days
    df = countries[countries['Country/Region' ] == i].tail(30)
    # set graph
    g = sns.lineplot(ax=ax, x='Date', y='Deaths', data=df, sort=False, linewidth=2)  

# set line style
ax.lines[0].set_linestyle("-")

# set date 
current_date = str(date) 

# remove spines
sns.despine(right=True, top=True)
sns.set_style('white')

# set TITLE
g.set_title("Logarithmic Scale - Countries with the most Covid-19 deaths over the last 30 days - {}".format(current_date))

# set extras
g.set_xlabel("")
plt.legend(top['legend'])
plt.xticks(rotation=45)
plt.show()

# save graph to a FILENAME
fig.savefig("Top10_countries_log.png")

# %% [markdown]
# ## Arizona timeseries

# %%
# AZ Deaths by Date, ICU and Population 
AZ = county_deaths[county_deaths['Province_State']=='Arizona']

# %%
# investigate AZ dataset
AZ.head()
# Out:
#           UID iso2 iso3  code3    FIPS    Admin2 Province_State  \
# 101  84004001   US  USA    840  4001.0    Apache        Arizona
# 102  84004003   US  USA    840  4003.0   Cochise        Arizona
# 103  84004005   US  USA    840  4005.0  Coconino        Arizona
# 104  84004007   US  USA    840  4007.0      Gila        Arizona
# 105  84004009   US  USA    840  4009.0    Graham        Arizona
#
#     Country_Region        Lat       Long_  ... cnty_fips  cnty_name  st  \
# 101             US  35.394650 -109.489238  ...    4001.0     Apache  AZ
# 102             US  31.879347 -109.751609  ...    4003.0    Cochise  AZ
# 103             US  35.838834 -111.770718  ...    4005.0   Coconino  AZ
# 104             US  33.801901 -110.813278  ...    4007.0       Gila  AZ
# 105             US  32.931669 -109.888218  ...    4009.0     Graham  AZ
#
#        state  hospitals_in_cost_reports  Hospitals_in_HC  all_icu  Total_pop  \
# 101  Arizona                        4.0              4.0      0.0    71602.0
# 102  Arizona                        4.0              4.0     12.0   126516.0
# 103  Arizona                        3.0              3.0     41.0   138639.0
# 104  Arizona                        3.0              3.0      8.0    53145.0
# 105  Arizona                        1.0              1.0      0.0    37700.0
#
#       60plus  60plus_pct
# 101  14107.0       0.197
# 102  35231.0       0.278
# 103  23195.0       0.167
# 104  18752.0       0.353
# 105   6933.0       0.184
#
# [5 rows x 186 columns]

# %%
# drop extra columns (not dates)
drops = ['UID','iso2','iso3','code3','Province_State','Country_Region','cnty_fips','cnty_name','st','state','hospitals_in_cost_reports','Hospitals_in_HC','all_icu','Total_pop','60plus','60plus_pct']
AZ_dates = AZ.drop(drops, axis=1,inplace=False)
AZ_dates.tail()
# Out:
#          FIPS      Admin2        Lat       Long_             Combined_Key  \
# 113    4023.0  Santa Cruz  31.525090 -110.847909  Santa Cruz, Arizona, US
# 114    4025.0     Yavapai  34.599339 -112.553859     Yavapai, Arizona, US
# 115    4027.0        Yuma  32.768957 -113.906667        Yuma, Arizona, US
# 3159  80004.0   Out of AZ   0.000000    0.000000   Out of AZ, Arizona, US
# 3211  90004.0  Unassigned   0.000000    0.000000  Unassigned, Arizona, US
#
#       Population  1/22/20  1/23/20  1/24/20  1/25/20  ...  6/24/20  6/25/20  \
# 113        46498        0        0        0        0  ...       14       14
# 114       235099        0        0        0        0  ...        7        7
# 115       213787        0        0        0        0  ...       72       73
# 3159           0        0        0        0        0  ...        0        0
# 3211           0        0        0        0        0  ...        1        1
#
#       6/26/20  6/27/20  6/28/20  6/29/20  6/30/20  7/1/20  7/2/20  7/3/20
# 113        14       16       18       18       22      22      22      24
# 114         7        8        8        8        9      10      11      10
# 115        77       81       86       90       94      98     103     107
# 3159        0        0        0        0        0       0       0       0
# 3211        1        1        1        1        1       1       0       0
#
# [5 rows x 170 columns]

# %% [markdown]
# ## Calculating METRICS

# %%
# Yesterday's date

# Today's date
today = datetime.now()

# if time is after 5pm (Tucson time), then use today's date 
today5pm = today.replace(hour=17, minute=1, second=0, microsecond=0)
if today > today5pm:
    date_ext = today  

# otherwise use yesterday's date for data
else:
    date_ext = today - timedelta(1)
    
# define yesterday (external) is in datetime format
yesterday_ext = date_ext - timedelta(1)

# yesterday in string format
yesterday = yesterday_ext.strftime('%D').lstrip("0").replace(" 0", " ")
yesterday = yesterday.replace("/0", "/")
yesterday
# Out:
# '7/2/20'

# %%
# Add Changes , Pct_change, and Pct_pop columns
AZ_dates['Change'] = AZ_dates[date] - AZ_dates[yesterday]
AZ_dates['Pct_change'] = AZ_dates['Change']/AZ_dates[yesterday]*100
AZ_dates['Deaths_per_mil']= AZ_dates[date]/AZ_dates['Population']*1000000

# %% [markdown]
# ### Metrics for Total AZ Deaths by County

# %%
# Show list of counties and current deaths by Population size
AZ_dates = AZ_dates.sort_values(by='Population', ascending=False)

# Add all metrics - rounded
AZ_dates[['Combined_Key', 'Population', date,'Change', 'Pct_change','Deaths_per_mil']].round()
# Out:
#                  Combined_Key  Population  7/3/20  Change  Pct_change  \
# 108     Maricopa, Arizona, US     4485414     865      22         3.0
# 111         Pima, Arizona, US     1047279     282       2         1.0
# 112        Pinal, Arizona, US      462789      75       1         1.0
# 114      Yavapai, Arizona, US      235099      10      -1        -9.0
# 115         Yuma, Arizona, US      213787     107       4         4.0
# 109       Mohave, Arizona, US      212181      88       0         0.0
# 103     Coconino, Arizona, US      143476      96       1         1.0
# 102      Cochise, Arizona, US      125922      14       2        17.0
# 110       Navajo, Arizona, US      110924     132       1         1.0
# 101       Apache, Arizona, US       71887      91       0         0.0
# 104         Gila, Arizona, US       54018       6       0         0.0
# 113   Santa Cruz, Arizona, US       46498      24       2         9.0
# 105       Graham, Arizona, US       38837       1       0         0.0
# 107       La Paz, Arizona, US       21108       6       0         0.0
# 106     Greenlee, Arizona, US        9498       1       0         0.0
# 3159   Out of AZ, Arizona, US           0       0       0         NaN
# 3211  Unassigned, Arizona, US           0       0       0         NaN
#
#       Deaths_per_mil
# 108            193.0
# 111            269.0
# 112            162.0
# 114             43.0
# 115            500.0
# 109            415.0
# 103            669.0
# 102            111.0
# 110           1190.0
# 101           1266.0
# 104            111.0
# 113            516.0
# 105             26.0
# 107            284.0
# 106            105.0
# 3159             NaN
# 3211             NaN

# %% [markdown]
# ### AZ timeseries by county

# %%
# drop extra columns
AZ_dates.drop(['Change', 'Pct_change','Deaths_per_mil'], axis=1, inplace=True)
AZ_dates.tail()
# Out:
#          FIPS      Admin2        Lat       Long_             Combined_Key  \
# 105    4009.0      Graham  32.931669 -109.888218      Graham, Arizona, US
# 107    4012.0      La Paz  33.728542 -113.981003      La Paz, Arizona, US
# 106    4011.0    Greenlee  33.214988 -109.240528    Greenlee, Arizona, US
# 3159  80004.0   Out of AZ   0.000000    0.000000   Out of AZ, Arizona, US
# 3211  90004.0  Unassigned   0.000000    0.000000  Unassigned, Arizona, US
#
#       Population  1/22/20  1/23/20  1/24/20  1/25/20  ...  6/24/20  6/25/20  \
# 105        38837        0        0        0        0  ...        1        1
# 107        21108        0        0        0        0  ...        4        4
# 106         9498        0        0        0        0  ...        1        1
# 3159           0        0        0        0        0  ...        0        0
# 3211           0        0        0        0        0  ...        1        1
#
#       6/26/20  6/27/20  6/28/20  6/29/20  6/30/20  7/1/20  7/2/20  7/3/20
# 105         1        1        1        1        1       1       1       1
# 107         5        5        5        5        5       5       6       6
# 106         1        1        1        1        1       1       1       1
# 3159        0        0        0        0        0       0       0       0
# 3211        1        1        1        1        1       1       0       0
#
# [5 rows x 170 columns]

# %%
# melt dataset - Keep certain columns and change others to vertical axis(?)
AZ_counties = pd.melt(AZ_dates, id_vars=AZ_dates.iloc[:, :6],
var_name='Date', value_name='Deaths')
AZ_counties
# Out:
#          FIPS      Admin2        Lat       Long_             Combined_Key  \
# 0      4013.0    Maricopa  33.348359 -112.491815    Maricopa, Arizona, US
# 1      4019.0        Pima  32.097133 -111.789003        Pima, Arizona, US
# 2      4021.0       Pinal  32.905256 -111.344948       Pinal, Arizona, US
# 3      4025.0     Yavapai  34.599339 -112.553859     Yavapai, Arizona, US
# 4      4027.0        Yuma  32.768957 -113.906667        Yuma, Arizona, US
# ...       ...         ...        ...         ...                      ...
# 2783   4009.0      Graham  32.931669 -109.888218      Graham, Arizona, US
# 2784   4012.0      La Paz  33.728542 -113.981003      La Paz, Arizona, US
# 2785   4011.0    Greenlee  33.214988 -109.240528    Greenlee, Arizona, US
# 2786  80004.0   Out of AZ   0.000000    0.000000   Out of AZ, Arizona, US
# 2787  90004.0  Unassigned   0.000000    0.000000  Unassigned, Arizona, US
#
#       Population     Date  Deaths
# 0        4485414  1/22/20       0
# 1        1047279  1/22/20       0
# 2         462789  1/22/20       0
# 3         235099  1/22/20       0
# 4         213787  1/22/20       0
# ...          ...      ...     ...
# 2783       38837   7/3/20       1
# 2784       21108   7/3/20       6
# 2785        9498   7/3/20       1
# 2786           0   7/3/20       0
# 2787           0   7/3/20       0
#
# [2788 rows x 8 columns]

# %%
# add a column for LEGEND to top
AZ_counties['legend']= AZ_counties['Admin2'] + ' - ' + AZ_counties['Deaths'].astype(str)
AZ_counties
# Out:
#          FIPS      Admin2        Lat       Long_             Combined_Key  \
# 0      4013.0    Maricopa  33.348359 -112.491815    Maricopa, Arizona, US
# 1      4019.0        Pima  32.097133 -111.789003        Pima, Arizona, US
# 2      4021.0       Pinal  32.905256 -111.344948       Pinal, Arizona, US
# 3      4025.0     Yavapai  34.599339 -112.553859     Yavapai, Arizona, US
# 4      4027.0        Yuma  32.768957 -113.906667        Yuma, Arizona, US
# ...       ...         ...        ...         ...                      ...
# 2783   4009.0      Graham  32.931669 -109.888218      Graham, Arizona, US
# 2784   4012.0      La Paz  33.728542 -113.981003      La Paz, Arizona, US
# 2785   4011.0    Greenlee  33.214988 -109.240528    Greenlee, Arizona, US
# 2786  80004.0   Out of AZ   0.000000    0.000000   Out of AZ, Arizona, US
# 2787  90004.0  Unassigned   0.000000    0.000000  Unassigned, Arizona, US
#
#       Population     Date  Deaths          legend
# 0        4485414  1/22/20       0    Maricopa - 0
# 1        1047279  1/22/20       0        Pima - 0
# 2         462789  1/22/20       0       Pinal - 0
# 3         235099  1/22/20       0     Yavapai - 0
# 4         213787  1/22/20       0        Yuma - 0
# ...          ...      ...     ...             ...
# 2783       38837   7/3/20       1      Graham - 1
# 2784       21108   7/3/20       6      La Paz - 6
# 2785        9498   7/3/20       1    Greenlee - 1
# 2786           0   7/3/20       0   Out of AZ - 0
# 2787           0   7/3/20       0  Unassigned - 0
#
# [2788 rows x 9 columns]

# %%
# SET subplot size
fig, ax = plt.subplots(figsize=(10, 6))  

# # set log scale
# ax.set(yscale="log")
# ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)) )

# set ATTRIBUTEs for each dataset
for i in AZ_counties['Admin2']:
    # set data to last 30 days
    df = AZ_counties[AZ_counties['Admin2'] == i].tail(30)
    # set graph
    g = sns.lineplot(ax=ax, x='Date', y='Deaths', data=df, sort=False, linewidth=2)  

# set line style
ax.lines[0].set_linestyle("-")

# set date 
current_date = str(date) 

# remove spines
sns.despine(right=True, top=True)
sns.set_style('white')

# set TITLE
g.set_title("AZ Covid-19 deaths over the last 30 days - {}".format(current_date))

# set extras
g.set_xlabel("")
plt.xticks(rotation=45)
plt.show()

# save graph to a FILENAME
fig.savefig("AZ_counties.png")

# %% [markdown]
# ### STUCK ON GETTING THE LEGEND RIGHT!
# #### They relabeled some entries  on 4/18/20. Pima has just started reporting more regularly than once or twice a week!

# %% [markdown]
# ## Calculating Pima PCT_CHANGE

# %%
Pima_dates=AZ_dates[AZ_dates['Admin2']=='Pima'].copy()
Pima_dates
# Out:
#        FIPS Admin2        Lat       Long_       Combined_Key  Population  \
# 111  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
#
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  6/24/20  6/25/20  6/26/20  \
# 111        0        0        0        0  ...      255      272      266
#
#      6/27/20  6/28/20  6/29/20  6/30/20  7/1/20  7/2/20  7/3/20
# 111      268      268      268      273     280     280     282
#
# [1 rows x 170 columns]

# %%
# unpivot DataFrame from wide to long format, optionally leaving identifiers set.
Pima_long = pd.melt(Pima_dates, id_vars=Pima_dates.iloc[:,:6],
var_name='Date', value_name='Deaths')
Pima_long.tail()
# Out:
#        FIPS Admin2        Lat       Long_       Combined_Key  Population  \
# 159  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 160  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 161  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 162  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 163  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
#
#         Date  Deaths
# 159  6/29/20     268
# 160  6/30/20     273
# 161   7/1/20     280
# 162   7/2/20     280
# 163   7/3/20     282

# %%
Pima30 = Pima_long.copy().tail(30)
Pima30[['PC']]=Pima30[['Deaths']].pct_change()
Pima30.tail()
# Out:
#        FIPS Admin2        Lat       Long_       Combined_Key  Population  \
# 159  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 160  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 161  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 162  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 163  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
#
#         Date  Deaths        PC
# 159  6/29/20     268  0.000000
# 160  6/30/20     273  0.018657
# 161   7/1/20     280  0.025641
# 162   7/2/20     280  0.000000
# 163   7/3/20     282  0.007143

# %%
# set dataset for graphs
df = Pima30
df=df[df['Deaths']>0]
df.tail(10)
# Out:
#        FIPS Admin2        Lat       Long_       Combined_Key  Population  \
# 154  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 155  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 156  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 157  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 158  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 159  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 160  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 161  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 162  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
# 163  4019.0   Pima  32.097133 -111.789003  Pima, Arizona, US     1047279
#
#         Date  Deaths        PC
# 154  6/24/20     255  0.032389
# 155  6/25/20     272  0.066667
# 156  6/26/20     266 -0.022059
# 157  6/27/20     268  0.007519
# 158  6/28/20     268  0.000000
# 159  6/29/20     268  0.000000
# 160  6/30/20     273  0.018657
# 161   7/1/20     280  0.025641
# 162   7/2/20     280  0.000000
# 163   7/3/20     282  0.007143

# %%
# simple timeseries graph
fig, ax = plt.subplots(figsize=(16, 6))
sns.lineplot(x='Date', y='Deaths', data=df, sort=False, linewidth=2)
sns.despine(right=True, top=True)
ax.lines[0].set_linestyle("--")
plt.xticks(rotation=45)
ax.legend(['Pima County - reporting lags until 4/19/20']) 
plt.title("AZ - Pima County - Covid-19 Deaths - {}".format(str(date)))
plt.show()
# save graph to a file
fig.savefig("Pima_deaths.png")

# %% [markdown]
# ###### What do I do when reporting is like this? Does ML take this into account?

# %% [markdown]
# Should I redo the dataset to weekly? Trailing 7 day? Trailing 3 day?

# %% [markdown]
# ## TO DO:
# 1. Change data to look at increment per day per country - KEY!!!!!!!!!
# 2. Look at rate of increase
# 3. Look at time-series - # of days vs # of deaths, # of days vs. # of cases
# 4. Separate out test cases vs training case
#     - US separately is the Test case
#     - outlier - South Korea, Singapore, China
#     - ROW is the training case
# 5. Look at 2 plots
#     - in deaths
#     - in deaths as a % of pop
